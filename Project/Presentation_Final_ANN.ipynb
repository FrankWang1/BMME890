# %% [markdown]
# # BMME890 - Fall 2019
#
# ## Wine Quality Project
#
# Group: Nhan Pham, Khoi Huynh, Frank Wang, and Jiayi Xu

# %% [markdown]
# ### Classification
#
# - Multilabel classification problem
# - Labels: $0 - 10$
# - Methods: ANN

# %%
import numpy as np
import pandas as pd
import matplotlib 
import seaborn as sns
from matplotlib import pyplot as plt

# %%
whiteset=pd.read_csv('winequality-white.csv')
redset=pd.read_csv('winequality-red.csv')
whiteset_added=whiteset
whiteset_added['type']='white'
redset_added=redset
redset_added['type']='red'
frames=[whiteset_added, redset_added]
dataset=pd.concat(frames,ignore_index=True)
dataset=dataset[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','type','quality']]
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol   type  quality
# 0      8.8  white        6
# 1      9.5  white        6
# 2     10.1  white        6
# 3      9.9  white        6
# 4      9.9  white        6

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
dataset.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# type                    0
# quality                 0
# dtype: int64

# %% [markdown]
# ## Note:
#
# - The data look clean, no capped value, no missing values.
# - Too few samples for quality <= 3 and >=9.

# %%
f, ax = plt.subplots(figsize=(11, 15)) 
corr_matrix = dataset.corr()
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)]= True
heatmap = sns.heatmap(corr_matrix, mask = mask, square = True, linewidths = .5, cmap = 'coolwarm',
                      cbar_kws = {'shrink': .4, 
                                'ticks' : [-1, -.5, 0, 0.5, 1]},
                      vmin = -1, 
                      vmax = 1,
                      annot = True,
                      annot_kws = {"size": 12})
#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %%
dataset=pd.get_dummies(dataset)
dataset=dataset[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','type_red','type_white','quality']]
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  type_red  type_white  quality
# 0      8.8         0           1        6
# 1      9.5         0           1        6
# 2     10.1         0           1        6
# 3      9.9         0           1        6
# 4      9.9         0           1        6

# %%
import sklearn
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_index, test_index in split.split(dataset, dataset["quality"]):
    strat_train_set = dataset.loc[train_index]
    strat_test_set = dataset.loc[test_index]
    
X_train=pd.DataFrame(strat_train_set[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','type_red','type_white']])
X_test=pd.DataFrame(strat_test_set[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol','type_red','type_white']])

y_train=strat_train_set.quality
y_test=strat_test_set.quality

print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# 6    2269
# 5    1710
# 7     863
# 4     173
# 8     154
# 3      24
# 9       4
# Name: quality, dtype: int64
# 6    567
# 5    428
# 7    216
# 4     43
# 8     39
# 3      6
# 9      1
# Name: quality, dtype: int64

# %%
X_train_means = X_train.mean(axis=0)
X_train_stds = X_train.std(axis=0)

X_test_means = X_test.mean(axis=0)
X_test_stds = X_test.std(axis=0)

X_train_scaled = (X_train - X_train_means) / X_train_stds
X_test_scaled = (X_test - X_test_means) / X_test_stds

y_train_cat = y_train - np.amin(y_train)
y_test_cat = y_test - np.amin(y_test)

num_class = 7

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import GaussianNoise, BatchNormalization, Dropout
import keras
from tensorflow.keras import backend as K
import tensorflow as tf
from datetime import datetime
from tensorflow.keras import metrics
from tensorflow.keras import regularizers

input_shape = (None, 13)

def top2_acc(labels, logits): 
    return metrics.sparse_top_k_categorical_accuracy(y_true=labels, y_pred=logits, k=2)

def white_wine_model():
    model = Sequential()
    model.add(Flatten())
    
    model.add(BatchNormalization())
    
    
    
    model.add(Dense(400, activation='selu',kernel_initializer="lecun_normal"))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    
    for i in range(5):
        model.add(Dense(500, 
                    activation='selu',kernel_initializer="lecun_normal"))
        model.add(BatchNormalization())
        model.add(Dropout(0.4))
    
    model.add(Dense(num_class, 
                    activation='softmax'))

    model.compile(loss=tf.keras.losses.sparse_categorical_crossentropy,
                optimizer=tf.keras.optimizers.Adam(lr=0.001),
                metrics=['accuracy', top2_acc])
    
    return model

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

model = white_wine_model()

training_history = model.fit(
    X_train.to_numpy(),#x_train.to_numpy(), # input
    y_train_cat.to_numpy(),#y_train_cat.to_numpy(), # output
    batch_size=32,
    verbose=2, # Suppress chatty output; use Tensorboard instead
    epochs=60,
     validation_data=(X_test.to_numpy(), y_test_cat.to_numpy()))
# Out:
# Using TensorFlow backend.
# Train on 5197 samples, validate on 1300 samples
# Epoch 1/60
# 5197/5197 - 7s - loss: 1.9997 - accuracy: 0.3771 - top2_acc: 0.6055 - val_loss: 2.7033 - val_accuracy: 0.2446 - val_top2_acc: 0.4231
# Epoch 2/60
# 5197/5197 - 3s - loss: 1.3921 - accuracy: 0.4689 - top2_acc: 0.7853 - val_loss: 1.2303 - val_accuracy: 0.5123 - val_top2_acc: 0.8200
# Epoch 3/60
# 5197/5197 - 3s - loss: 1.2781 - accuracy: 0.4664 - top2_acc: 0.8126 - val_loss: 1.1146 - val_accuracy: 0.5446 - val_top2_acc: 0.8546
# Epoch 4/60
# 5197/5197 - 3s - loss: 1.2002 - accuracy: 0.4914 - top2_acc: 0.8236 - val_loss: 1.0915 - val_accuracy: 0.5385 - val_top2_acc: 0.8623
# Epoch 5/60
# 5197/5197 - 3s - loss: 1.1686 - accuracy: 0.5080 - top2_acc: 0.8309 - val_loss: 1.1189 - val_accuracy: 0.5354 - val_top2_acc: 0.8508
# Epoch 6/60
# 5197/5197 - 3s - loss: 1.1584 - accuracy: 0.5034 - top2_acc: 0.8347 - val_loss: 1.0695 - val_accuracy: 0.5431 - val_top2_acc: 0.8538
# Epoch 7/60
# 5197/5197 - 3s - loss: 1.1352 - accuracy: 0.5149 - top2_acc: 0.8434 - val_loss: 1.0676 - val_accuracy: 0.5262 - val_top2_acc: 0.8592
# Epoch 8/60
# 5197/5197 - 3s - loss: 1.1305 - accuracy: 0.5263 - top2_acc: 0.8439 - val_loss: 1.0618 - val_accuracy: 0.5469 - val_top2_acc: 0.8638
# Epoch 9/60
# 5197/5197 - 3s - loss: 1.1137 - accuracy: 0.5140 - top2_acc: 0.8430 - val_loss: 1.0584 - val_accuracy: 0.5638 - val_top2_acc: 0.8569
# Epoch 10/60
# 5197/5197 - 3s - loss: 1.1211 - accuracy: 0.5193 - top2_acc: 0.8457 - val_loss: 1.0479 - val_accuracy: 0.5277 - val_top2_acc: 0.8569
# Epoch 11/60
# 5197/5197 - 3s - loss: 1.1093 - accuracy: 0.5243 - top2_acc: 0.8505 - val_loss: 1.0812 - val_accuracy: 0.5200 - val_top2_acc: 0.8638
# Epoch 12/60
# 5197/5197 - 3s - loss: 1.1063 - accuracy: 0.5186 - top2_acc: 0.8501 - val_loss: 1.0489 - val_accuracy: 0.5523 - val_top2_acc: 0.8692
# Epoch 13/60
# 5197/5197 - 3s - loss: 1.1028 - accuracy: 0.5286 - top2_acc: 0.8513 - val_loss: 1.0367 - val_accuracy: 0.5462 - val_top2_acc: 0.8746
# Epoch 14/60
# 5197/5197 - 4s - loss: 1.0921 - accuracy: 0.5295 - top2_acc: 0.8524 - val_loss: 1.0728 - val_accuracy: 0.5162 - val_top2_acc: 0.8623
# Epoch 15/60
# 5197/5197 - 3s - loss: 1.0872 - accuracy: 0.5290 - top2_acc: 0.8540 - val_loss: 1.0325 - val_accuracy: 0.5446 - val_top2_acc: 0.8700
# Epoch 16/60
# 5197/5197 - 3s - loss: 1.0748 - accuracy: 0.5299 - top2_acc: 0.8563 - val_loss: 1.0598 - val_accuracy: 0.5415 - val_top2_acc: 0.8600
# Epoch 17/60
# 5197/5197 - 3s - loss: 1.0836 - accuracy: 0.5257 - top2_acc: 0.8532 - val_loss: 1.0473 - val_accuracy: 0.5392 - val_top2_acc: 0.8623
# Epoch 18/60
# 5197/5197 - 3s - loss: 1.0767 - accuracy: 0.5338 - top2_acc: 0.8563 - val_loss: 1.0341 - val_accuracy: 0.5485 - val_top2_acc: 0.8638
# Epoch 19/60
# 5197/5197 - 3s - loss: 1.0780 - accuracy: 0.5322 - top2_acc: 0.8603 - val_loss: 1.0445 - val_accuracy: 0.5531 - val_top2_acc: 0.8708
# Epoch 20/60
# 5197/5197 - 3s - loss: 1.0657 - accuracy: 0.5388 - top2_acc: 0.8563 - val_loss: 1.0510 - val_accuracy: 0.5208 - val_top2_acc: 0.8646
# Epoch 21/60
# 5197/5197 - 3s - loss: 1.0757 - accuracy: 0.5322 - top2_acc: 0.8534 - val_loss: 1.0395 - val_accuracy: 0.5392 - val_top2_acc: 0.8731
# Epoch 22/60
# 5197/5197 - 3s - loss: 1.0702 - accuracy: 0.5469 - top2_acc: 0.8516 - val_loss: 1.0671 - val_accuracy: 0.5392 - val_top2_acc: 0.8677
# Epoch 23/60
# 5197/5197 - 3s - loss: 1.0669 - accuracy: 0.5386 - top2_acc: 0.8536 - val_loss: 1.0272 - val_accuracy: 0.5646 - val_top2_acc: 0.8600
# Epoch 24/60
# 5197/5197 - 3s - loss: 1.0716 - accuracy: 0.5434 - top2_acc: 0.8591 - val_loss: 1.0432 - val_accuracy: 0.5492 - val_top2_acc: 0.8492
# Epoch 25/60
# 5197/5197 - 3s - loss: 1.0516 - accuracy: 0.5397 - top2_acc: 0.8609 - val_loss: 1.0534 - val_accuracy: 0.5338 - val_top2_acc: 0.8592
# Epoch 26/60
# 5197/5197 - 3s - loss: 1.0595 - accuracy: 0.5349 - top2_acc: 0.8584 - val_loss: 1.0753 - val_accuracy: 0.4831 - val_top2_acc: 0.8708
# Epoch 27/60
# 5197/5197 - 4s - loss: 1.0611 - accuracy: 0.5438 - top2_acc: 0.8561 - val_loss: 1.0271 - val_accuracy: 0.5500 - val_top2_acc: 0.8715
# Epoch 28/60
# 5197/5197 - 3s - loss: 1.0562 - accuracy: 0.5361 - top2_acc: 0.8632 - val_loss: 1.0115 - val_accuracy: 0.5492 - val_top2_acc: 0.8823
# Epoch 29/60
# 5197/5197 - 4s - loss: 1.0559 - accuracy: 0.5403 - top2_acc: 0.8611 - val_loss: 1.0059 - val_accuracy: 0.5646 - val_top2_acc: 0.8777
# Epoch 30/60
# 5197/5197 - 4s - loss: 1.0524 - accuracy: 0.5403 - top2_acc: 0.8657 - val_loss: 1.0549 - val_accuracy: 0.5492 - val_top2_acc: 0.8715
# Epoch 31/60
# 5197/5197 - 4s - loss: 1.0455 - accuracy: 0.5486 - top2_acc: 0.8647 - val_loss: 1.0215 - val_accuracy: 0.5531 - val_top2_acc: 0.8723
# Epoch 32/60
# 5197/5197 - 3s - loss: 1.0453 - accuracy: 0.5395 - top2_acc: 0.8665 - val_loss: 0.9980 - val_accuracy: 0.5592 - val_top2_acc: 0.8823
# Epoch 33/60
# 5197/5197 - 4s - loss: 1.0389 - accuracy: 0.5576 - top2_acc: 0.8622 - val_loss: 1.0150 - val_accuracy: 0.5592 - val_top2_acc: 0.8777
# Epoch 34/60
# 5197/5197 - 4s - loss: 1.0410 - accuracy: 0.5447 - top2_acc: 0.8642 - val_loss: 1.0472 - val_accuracy: 0.5462 - val_top2_acc: 0.8769
# Epoch 35/60
# 5197/5197 - 4s - loss: 1.0400 - accuracy: 0.5465 - top2_acc: 0.8680 - val_loss: 0.9984 - val_accuracy: 0.5654 - val_top2_acc: 0.8762
# Epoch 36/60
# 5197/5197 - 3s - loss: 1.0353 - accuracy: 0.5463 - top2_acc: 0.8659 - val_loss: 1.0484 - val_accuracy: 0.5485 - val_top2_acc: 0.8708
# Epoch 37/60
# 5197/5197 - 3s - loss: 1.0329 - accuracy: 0.5419 - top2_acc: 0.8692 - val_loss: 1.0113 - val_accuracy: 0.5731 - val_top2_acc: 0.8692
# Epoch 38/60
# 5197/5197 - 3s - loss: 1.0465 - accuracy: 0.5449 - top2_acc: 0.8636 - val_loss: 0.9989 - val_accuracy: 0.5708 - val_top2_acc: 0.8792
# Epoch 39/60
# 5197/5197 - 3s - loss: 1.0272 - accuracy: 0.5509 - top2_acc: 0.8709 - val_loss: 1.0084 - val_accuracy: 0.5685 - val_top2_acc: 0.8723
# Epoch 40/60
# 5197/5197 - 4s - loss: 1.0279 - accuracy: 0.5484 - top2_acc: 0.8684 - val_loss: 1.0197 - val_accuracy: 0.5662 - val_top2_acc: 0.8808
# Epoch 41/60
# 5197/5197 - 3s - loss: 1.0228 - accuracy: 0.5546 - top2_acc: 0.8665 - val_loss: 1.0138 - val_accuracy: 0.5646 - val_top2_acc: 0.8746
# Epoch 42/60
# 5197/5197 - 4s - loss: 1.0202 - accuracy: 0.5638 - top2_acc: 0.8709 - val_loss: 1.0356 - val_accuracy: 0.5700 - val_top2_acc: 0.8631
# Epoch 43/60
# 5197/5197 - 4s - loss: 1.0217 - accuracy: 0.5626 - top2_acc: 0.8670 - val_loss: 1.0116 - val_accuracy: 0.5554 - val_top2_acc: 0.8800
# Epoch 44/60
# 5197/5197 - 4s - loss: 1.0202 - accuracy: 0.5563 - top2_acc: 0.8678 - val_loss: 1.0214 - val_accuracy: 0.5638 - val_top2_acc: 0.8708
# Epoch 45/60
# 5197/5197 - 4s - loss: 1.0228 - accuracy: 0.5519 - top2_acc: 0.8688 - val_loss: 0.9989 - val_accuracy: 0.5608 - val_top2_acc: 0.8838
# Epoch 46/60
# 5197/5197 - 3s - loss: 1.0218 - accuracy: 0.5569 - top2_acc: 0.8645 - val_loss: 1.0103 - val_accuracy: 0.5462 - val_top2_acc: 0.8869
# Epoch 47/60
# 5197/5197 - 3s - loss: 1.0287 - accuracy: 0.5519 - top2_acc: 0.8663 - val_loss: 1.0105 - val_accuracy: 0.5569 - val_top2_acc: 0.8754
# Epoch 48/60
# 5197/5197 - 3s - loss: 1.0242 - accuracy: 0.5430 - top2_acc: 0.8726 - val_loss: 1.0033 - val_accuracy: 0.5831 - val_top2_acc: 0.8731
# Epoch 49/60
# 5197/5197 - 3s - loss: 1.0018 - accuracy: 0.5621 - top2_acc: 0.8711 - val_loss: 1.0013 - val_accuracy: 0.5677 - val_top2_acc: 0.8862
# Epoch 50/60
# 5197/5197 - 4s - loss: 1.0068 - accuracy: 0.5655 - top2_acc: 0.8701 - val_loss: 1.0129 - val_accuracy: 0.5631 - val_top2_acc: 0.8746
# Epoch 51/60
# 5197/5197 - 4s - loss: 1.0068 - accuracy: 0.5649 - top2_acc: 0.8674 - val_loss: 1.0050 - val_accuracy: 0.5677 - val_top2_acc: 0.8823
# Epoch 52/60
# 5197/5197 - 4s - loss: 1.0106 - accuracy: 0.5594 - top2_acc: 0.8717 - val_loss: 0.9948 - val_accuracy: 0.5662 - val_top2_acc: 0.8823
# Epoch 53/60
# 5197/5197 - 4s - loss: 1.0121 - accuracy: 0.5605 - top2_acc: 0.8690 - val_loss: 1.0017 - val_accuracy: 0.5823 - val_top2_acc: 0.8823
# Epoch 54/60
# 5197/5197 - 4s - loss: 1.0096 - accuracy: 0.5596 - top2_acc: 0.8717 - val_loss: 1.0262 - val_accuracy: 0.5638 - val_top2_acc: 0.8815
# Epoch 55/60
# 5197/5197 - 4s - loss: 1.0007 - accuracy: 0.5655 - top2_acc: 0.8713 - val_loss: 1.0418 - val_accuracy: 0.5608 - val_top2_acc: 0.8715
# Epoch 56/60
# 5197/5197 - 4s - loss: 1.0042 - accuracy: 0.5584 - top2_acc: 0.8692 - val_loss: 1.0028 - val_accuracy: 0.5569 - val_top2_acc: 0.8792
# Epoch 57/60
# 5197/5197 - 4s - loss: 1.0037 - accuracy: 0.5676 - top2_acc: 0.8709 - val_loss: 1.0158 - val_accuracy: 0.5638 - val_top2_acc: 0.8785
# Epoch 58/60
# 5197/5197 - 4s - loss: 1.0032 - accuracy: 0.5653 - top2_acc: 0.8690 - val_loss: 0.9947 - val_accuracy: 0.5815 - val_top2_acc: 0.8785
# Epoch 59/60
# 5197/5197 - 4s - loss: 0.9962 - accuracy: 0.5724 - top2_acc: 0.8718 - val_loss: 1.0105 - val_accuracy: 0.5615 - val_top2_acc: 0.8723
# Epoch 60/60
# 5197/5197 - 4s - loss: 0.9872 - accuracy: 0.5755 - top2_acc: 0.8801 - val_loss: 1.0018 - val_accuracy: 0.5554 - val_top2_acc: 0.8715

# %%
plt.plot(training_history.history['val_accuracy'])
plt.plot(training_history.history['accuracy'])
plt.legend(['ValAcc','TrainAcc'])
plt.title('Top 1 Accuracy')
# Out:
# Text(0.5, 1.0, 'Top 1 Accuracy')

# %%
plt.plot(training_history.history['val_top2_acc'])
plt.plot(training_history.history['top2_acc'])
plt.legend(['ValAcc','TrainAcc'])
plt.title('Top 2 Accuracy')
plt.show()
